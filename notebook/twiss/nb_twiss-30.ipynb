# %% [markdown]
# # Example-##: Induced coupling

# %%
ok, i remember how to use phase
vary skew and observe phase (on line)
vary gxx (off line)
for some value  would be ?
FOR SOME value of gxy and gyx -> phase will not change by skew
look at phase derivative ?

# %%
bpm -- beam frame fit is still not good for cross terms
scanmighht help hre

# %%
in induced coupling the expressions below are not used directly
instead coupling is added and then gxy and gyx are fitted to get equal?

# %%
from induced coupling?
can use exact expression for phases or first order

# gxy->-((n11 Cos[fxx] Sec[fxx_bpm] Sin[fxx-fxx_bpm])/n32)
# gyx->-((n33 Cos[fyy] Sec[fyy_bpm] Sin[fyy-fyy_bpm])/n14)

all elements can be computed with coupling

can use amplitudes to improve these elements

n14 and n32 are with good improve

# initial lattice with some residual coupling?

# %%
wait
are these from these?
they migh not work
#    In coupled case, measured phases are effected by calibration errors (see Example-20)
#    tan fxx = (fx.sin() * (gxx * n[0, 0] + gxy * n[2, 0]) + fx.cos() * gxy * n[2, 1]) / (fx.cos() * (gxx * n[0, 0] + gxy * n[2, 0]) - gxy * fx.sin() * n[2, 1])
#    tan fxy = (fy.cos() * gxx * n[0, 3] + fy.sin() * (gxx * n[0, 2] + gxy * n[2, 2])) / (-gxx * fy.sin() * n[0, 3] + fy.cos() * (gxx * n[0, 2] + gxy * n[2, 2]))
#    tan fyx = (fx.sin() * (gyx * n[0, 0] + gyy * n[2, 0]) + fx.cos() * gyy * n[2, 1]) /(fx.cos() * (gyx * n[0, 0] + gyy * n[2, 0]) - gyy * fx.sin() * n[2, 1])
#    tan fyy = (fy.cos() * gyx * n[0, 3] + fy.sin() * (gyx * n[0, 2] + gyy * n[2, 2])) / (-gyx * fy.sin() * n[0, 3] + fy.cos() * (gyx * n[0, 2] + gyy * n[2, 2]))
#    The difference dfx = fxx - fx and dfy = fyy - fy is assumed to be small
#    fx and fy are replaced by fxx and fyy in equations for fxy and fyx
#    These equations are added to minimization procedure
#    Note, equations for phases can be solved for cross talk errors (all other are assumed to be known)
#    gxy->(gxx (Cos[fy] (-fxy n[1,3]+n[1,4])+(n[1,3]+fxy n[1,4]) Sin[fy]))/(n[3,3] (fxy Cos[fy]-Sin[fy]))
#    gyx->(gyy (Cos[fx] (-fyx n[3,1]+n[3,2])+(n[3,1]+fyx n[3,2]) Sin[fx]))/(n[1,1] (fyx Cos[fx]-Sin[fx]))
#    These results can be used to get signs of gxy and gyx (also estimations of these coefficients)
#    Note, this is expected to work with nonzero coupling (coupling can be induced specificaly for this purpose)
