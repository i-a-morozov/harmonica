# %% [markdown]
# # Example-##: Calibratons (vary lattice)

# %%
change quads or skew (calibrations are not changed)
good approximations of bpm frame are n11, n33, n14 and n32
these elements depend on other elements, they can be obtained from scaled tbt (beam frame)
basicaly, for each value of normal / skew get 4 eqs can solve with ls + mc
can combine several changes to solve togther or compare
+mc
