# %% [markdown]
# # Example-##: Fit subset of normalizaton matrix elemets

# %%
good elements to fix n11, n33, n14 and n32
but scaled tbt will give on part n11 and n33
n14 and n32 can be fixed

# %%
the idea is the following
-- invariants from coupled twiss are good
-- use them to compute twiss from amplitude (all of them)
-- these parametrs have good accuracy and are in bpm frame
-- fix these parameters and fit other (also fix invariant)
-- are resulting parameters in bpm frame?

# %%
can be done with partuial , pass twiss? also use additional args with fixed values
can use to find signs, then correct coupling and use uncou0pled formulars

# %%
find all BPM frame? -> more equs for reegression in cal

# %%
Examp
